# %%
from interarray.plotting import gplot, compare
from interarray.heuristics import CPEW, OBEW, ClassicEW
from interarray.interarraylib import calcload
from interarray.farmrepo import g

# %%
g._fields
# Out:
# ('thanet',
#  'dantysk',
#  'horns',
#  'anholt',
#  'sands',
#  'ormonde',
#  'london',
#  'rbn',
#  'rbs',
#  'tess',
#  'tess3')

# %%
G1 = CPEW(g.london, capacity=6)
calcload(G1)
G2 = OBEW(g.london, capacity=6)
calcload(G2)
# Out:
# [87] WARNING <make_detour> more stales than needed: 1
# [87] WARNING <make_detour> more stales than needed: 1

# %%
compare((G1, G2))

# %%
gplot(G1, node_tag='label');
